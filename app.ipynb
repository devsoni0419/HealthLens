# %%
import gradio as gr
from rag.vector_store import search
from openai import OpenAI
from dotenv import load_dotenv
import os
import warnings

warnings.filterwarnings("ignore", module="chromadb")
load_dotenv(override=True)

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

SYSTEM_PROMPT = """
You are HealthLens, a medical information assistant.

Rules:
- Provide educational information only.
- Do NOT diagnose.
- Do NOT suggest medications.
- Do NOT give emergency instructions.
- Encourage consulting licensed healthcare professionals.
- If user asks for diagnosis or treatment, refuse politely.
"""

DISCLAIMER = """
⚠️ This response is for educational purposes only and is not medical advice.
Always consult a qualified healthcare professional.
"""

def generate_answer(user_query):
    results = search(user_query, top_k=5)
    context_chunks = results["documents"][0]
    context = "\n\n".join(context_chunks)

    prompt = f"""
Context:
{context}

User Question:
{user_query}
"""

    response = client.chat.completions.create(
        model="meta-llama/llama-3.3-70b-instruct:free",
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": prompt}
        ],
        temperature=0.2
    )

    final_answer = response.choices[0].message.content
    return final_answer + "\n\n" + DISCLAIMER


with gr.Blocks(title="HealthLens AI") as app:
    gr.Markdown("# 🏥 HealthLens AI")
    gr.Markdown("Educational medical assistant (Non-diagnostic)")

    chatbot = gr.Chatbot()
    msg = gr.Textbox(placeholder="Ask a medical question...")
    clear = gr.Button("Clear")

    def chat(user_message, history):
        answer = generate_answer(user_message)
        history.append((user_message, answer))
        return "", history

    msg.submit(chat, [msg, chatbot], [msg, chatbot])
    clear.click(lambda: None, None, chatbot, queue=False)

app.launch(share=True,browser=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import gradio as gr
# ----> 2 from rag.vector_store import search
#       3 from openai import OpenAI
#       4 from dotenv import load_dotenv
#
# File c:\Users\devso\HealthLens\rag\vector_store.py:1
# ----> 1 import chromadb
#       2 import json
#       3 from sentence_transformers import SentenceTransformer
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\chromadb\__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.auth.token import TokenTransportHeader
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\chromadb\api\__init__.py:7
#       5 from overrides import override
#       6 from chromadb.config import DEFAULT_DATABASE, DEFAULT_TENANT
# ----> 7 from chromadb.api.models.Collection import Collection
#       8 from chromadb.api.types import (
#       9     CollectionMetadata,
#      10     Documents,
#    (...)     23     WhereDocument,
#      24 )
#      25 from chromadb.config import Component, Settings
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\chromadb\api\models\Collection.py:7
#       4 from pydantic import BaseModel, PrivateAttr
#       6 from uuid import UUID
# ----> 7 import chromadb.utils.embedding_functions as ef
#       9 from chromadb.api.types import (
#      10     URI,
#      11     CollectionMetadata,
#    (...)     47     validate_embedding_function,
#      48 )
#      49 import logging
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\chromadb\utils\embedding_functions.py:7
#       3 from functools import cached_property
#       5 from tenacity import stop_after_attempt, wait_random, retry, retry_if_exception
# ----> 7 from chromadb.api.types import (
#       8     Document,
#       9     Documents,
#      10     Embedding,
#      11     Image,
#      12     Images,
#      13     EmbeddingFunction,
#      14     Embeddings,
#      15     is_image,
#      16     is_document,
#      17 )
#      19 from pathlib import Path
#      20 import os
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\chromadb\api\types.py:102
#      98     return cast(Documents, target)
#     101 # Images
# --> 102 ImageDType = Union[np.uint, np.int_, np.float_]
#     103 Image = NDArray[ImageDType]
#     104 Images = List[Image]
#
# File c:\Users\devso\HealthLens\.venv\Lib\site-packages\numpy\__init__.py:791, in __getattr__(attr)
#     788     raise AttributeError(__former_attrs__[attr], name=None)
#     790 if attr in __expired_attributes__:
# --> 791     raise AttributeError(
#     792         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     793         f"{__expired_attributes__[attr]}",
#     794         name=None
#     795     )
#     797 if attr == "chararray":
#     798     warnings.warn(
#     799         "`np.chararray` is deprecated and will be removed from "
#     800         "the main namespace in the future. Use an array with a string "
#     801         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.
